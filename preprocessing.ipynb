# %%
import numpy as np 
import pandas as pd

from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv()
data.head()

# %%
data.shape

# %%
data.keys()

# %%
data.describe()

# %%
data.info()

# %%
data.isnaull().sum()

# %%
data['column_name'] = data['column_name'].fillna()
data.dropna(subset=['column_name'])

# %%
x_train, x_test, y_train, y_test = train_test_split()
