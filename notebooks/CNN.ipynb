# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.datasets import load_digits

# %%
data  = load_digits()
data.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'shape'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 data  = load_digits()
# ----> 2 data.shape
#
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:59, in Bunch.__getattr__(self, key)
#      57     return self[key]
# ...

# %%
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:57, in Bunch.__getattr__(self, key)
#      56 try:
# ---> 57     return self[key]
#      58 except KeyError:
#
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:42, in Bunch.__getitem__(self, key)
#      38     warnings.warn(
#      39         self._deprecated_key_to_warnings[key],
#      40         FutureWarning,
#      41     )
# ---> 42 return super().__getitem__(key)
#
# KeyError: 'head'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 data.head()
#
# File /usr/lib/python3.14/site-packages/sklearn/utils/_bunch.py:59, in Bunch.__getattr__(self, key)
#      57     return self[key]
#      58 except KeyError:
# ...
