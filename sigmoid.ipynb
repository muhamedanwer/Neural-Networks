# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

# %%
def sigmoid(net):
    return (1/1(1+np.exp(-net)))
# Out:
# <>:2: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# <>:2: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# /tmp/ipykernel_70460/3357495097.py:2: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   return (1/1(1+np.exp(-net)))

# %%
net = np.arange(-10,10,0.1)
y = sigmoid(net)
plt.plot(net,y)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 net = np.arange(-10,10,0.1)
# ----> 2 y = sigmoid(net)
#       3 plt.plot(net,y)
#       4 plt.grid()
#
# Cell In[13], line 2, in sigmoid(net)
#       1 def sigmoid(net):
# ----> 2     return (1/1(1+np.exp(-net)))
#
# TypeError: 'int' object is not callable
